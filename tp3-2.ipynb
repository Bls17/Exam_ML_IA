# %%
#Etape2
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Appliquer K-Means
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(data_scaled)

# Ajouter les labels de clusters au DataFrame
data['Cluster'] = kmeans.labels_

# Afficher les groupes résultants
print(data)

# Visualisation des clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(
    x=data["Temperature"], y=data["Precipitation"], hue=data["Cluster"], palette="viridis", s=100
)
plt.title("K-Means Clustering (3 Clusters)", fontsize=16)
plt.xlabel("Temperature", fontsize=12)
plt.ylabel("Precipitation", fontsize=12)
plt.legend(title="Cluster", fontsize=10)
plt.show()
# Out:
#    Temperature  Precipitation  Humidity  Cluster
# 0           25            0.1        80        1
# 1           30            0.0        75        2
# 2           28            0.3        78        0
# 3           22            0.2        82        1
# 4           35            0.4        70        0
# 5           29            0.2        76        0
# 6           27            0.1        79        1
# 7           26            0.3        77        0

# %%
#Exercice 2 etape1
import pandas as pd

data= pd.read_csv("data.csv")
selected_columns = ["Temperature", "Precipitation", "Humidity"]
data_clustering = data[selected_columns]

print(data_clustering)
# Out:
#      Temperature  Precipitation  Humidity
# 0            8.9              5      56.9
# 1           11.3              0      44.2
# 2           10.1              0      64.4
# 3            8.8              5      50.1
# 4           11.0              0      64.8
# ..           ...            ...       ...
# 995         11.5             10      45.6
# 996          6.7              0      44.2
# 997         17.9              0      50.6
# 998         15.1              0      53.6
# 999          8.0              0      35.9
#
# [1000 rows x 3 columns]
