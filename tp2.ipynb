# %%
#Etape 6
import plotly.express as px
Fig = px.bar(x=data["Temperature"], y=data["Date"])
fig.write_html('first_figure.html', auto_open=True)

# %%
#Etape 5
data['Date'] = pd.to_datetime(data['Date'])
correlation = data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Ajouter des titres
plt.title("Matrice de Corrélation", fontsize=16)
plt.show()

# %%
#Etape 4
fig, ax1 = plt.subplots(figsize=(10, 6))

# Tracer la courbe des températures sur le premier axe y
ax1.plot(data['Date'], data['Temperature'], color='tab:blue', marker='o', label='Température (°C)')
ax1.set_xlabel('Date')
ax1.set_ylabel('Température (°C)', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Créer un deuxième axe y pour les précipitations
ax2 = ax1.twinx()
ax2.plot(data['Date'], data['Precipitation'], color='tab:green', marker='x', label='Précipitations (mm)')
ax2.set_ylabel('Précipitations (mm)', color='tab:green')
ax2.tick_params(axis='y', labelcolor='tab:green')

# Ajouter des titres et ajuster la disposition
plt.title('Températures et Précipitations au fil du temps')
fig.tight_layout()  # Ajuster l'espacement pour éviter les chevauchements

# Afficher le graphique
plt.show()

# %%
#Etape 3
# Création du nuage de points avec régression
plt.figure(figsize=(10, 6))
sns.regplot(x='Temperature', y='Precipitation', data=data, color='blue', marker='o', line_kws={"color": "red"})
# Out:
# <Axes: xlabel='Temperature', ylabel='Precipitation'>

# %%
#Étape 2
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['Precipitation'], color='skyblue')

# Ajouter un titre
plt.title('Boxplot des Précipitations', fontsize=16)
plt.xlabel('Précipitations (mm)', fontsize=12)

# Afficher le graphique
plt.show()

# %%
#Étape 1
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("data.csv")

plt.hist(data["Temperature"],bins=10,edgecolor = "black")
plt.title("Histogramme des temperatures",fontsize = 16)
plt.xlabel("Temperature (°C)",fontsize = 12)
plt.ylabel("Frequences",fontsize = 12)
# Out:
# Text(0, 0.5, 'Frequences')
