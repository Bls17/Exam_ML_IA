# %%
#Etape 10 
data.to_csv('data.csv', index=False, sep=',', encoding='utf-8')

print("Le DataFrame transformé a été enregistré dans le fichier 'data_.csv'")
# Out:
# Le DataFrame transformé a été enregistré dans le fichier 'data_.csv'

# %%
#Etape 9
correlation = data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Ajouter des titres
plt.title("Matrice de Corrélation", fontsize=16)
plt.show()

# %%
#Etape 8
import matplotlib.pyplot as plt

# Assurez-vous que la colonne 'Date' est au format datetime
data['Date'] = pd.to_datetime(data['Date'])

# Tracer le graphique
plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Temperature'], marker='o', linestyle='-', color='g', label='Température')

# Ajouter des titres et des légendes
plt.title('Variation de la Température en fonction du Temps', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Température (°C)', fontsize=12)
plt.grid(True)
plt.legend(fontsize=12)
plt.tight_layout()

# Afficher le graphique
plt.show()

# %%
#Etape 7
sns.scatterplot(x="Temperature",y="Precipitation",data=data)
# Out:
# <Axes: xlabel='Temperature', ylabel='Precipitation'>

# %%
#Etape 6
plt.hist(data["Temperature"], bins=20, edgecolor='black')
plt.title('Distribution des Températures', fontsize=16)
plt.xlabel('Températures (°C)', fontsize=12)
plt.ylabel('Fréquence', fontsize=12)
# Out:
# Text(0, 0.5, 'Fréquence')

# %%
#Etape 5
hot_days =data[data['Temperature'] > 30]
print(hot_days)
# Out:
#                     Date  Temperature  Precipitation  Humidity   Latitude  \
# 209  2023-03-12 05:00:00         30.5              0      69.4   8.405223
# 220  2023-03-18 17:00:00         31.0             10      83.7  86.079720
# 295  2023-04-13 16:00:00         30.3              5      71.1 -42.132879
# 357  2023-05-04 02:00:00         30.4              0      84.4  45.624980
# 381  2023-05-13 20:00:00         30.5              0      71.9  25.470807
#
#       Longitude  Temperature_F  Is_Hot  Temp_Fahrenheit
# 209 -177.486386          86.90       1            86.90
# 220 -108.326369          87.80       1            87.80
# 295  137.122258          86.54       1            86.54
# 357  -60.417892          86.72       1            86.72
# 381 -109.264692          86.90       1            86.90

# %%
#Etape 4
data["Temp_Fahrenheit"] = data["Temperature"]* 9/5 +32

# %%
#Etape 3
valeurs_manquantes= data.isnull().sum()
value = data["Temperature"].mean()
non_null_value = data.fillna(value=value)

# %%
#Etape 2
data_description = data.describe()
max_temperature = data["Temperature"].max()
min_temperature = data["Temperature"].min()

print(min_temperature,max_temperature)
# Out:
# -12.4 31.0

# %%
#Étape 1
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("weather_data_1000.csv")
data_shape = data.shape
data_type = data.dtypes

print(data_shape,data_type)
# Out:
# (1000, 8) Date              object
# Temperature      float64
# Precipitation      int64
# Humidity         float64
# Latitude         float64
# Longitude        float64
# Temperature_F    float64
# Is_Hot             int64
# dtype: object
